# %% [markdown]
# 이름   : 김수지
# 학번  : 202044100

# %% [markdown]
# #교통사고 데이터 시각화

# %%
# 단계 1: 폰트 설치
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# !apt-get -qq -y install fonts-nanum > /dev/null



fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False

# 한글 폰트 설정
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설치

# %%
import pandas as pd
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# CSV 파일 읽기
file_path = '/content/도로교통공단_최근5년 교통사고 통계_20221231.csv'
data = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['사망자수', '중상자수', '경상자수', '부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

sns.lineplot(x='발생년', y='사고건수', data=data, color='r', marker='o', linestyle='--')
sns.set_style('darkgrid')

# 그래프 제목과 축 레이블 설정
plt.rc('font', family='NanumBarunGothic')
plt.title('최근 5년 동안의 교통사고 발생건수 추이')
plt.xlabel('년도', fontsize = 15)
plt.ylabel('발생건수', fontsize = 15)
# Out:
# Text(0, 0.5, '발생건수')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)



# CSV 파일 읽기
file_path = '/content/도로교통공단_최근5년 교통사고 통계_20221231.csv'
data = pd.read_csv(file_path, encoding='cp949')

plt.figure(figsize=(7, 6))

data

# 각 변수에 대한 lineplot 그래프 그리기
sns.lineplot(data=data, x='발생년', y='사고건수', label='사고건수', marker='o')
sns.lineplot(data=data, x='발생년', y='사망자수', label='사망자수', marker='o')
sns.lineplot(data=data, x='발생년', y='중상자수', label='중상자수', marker='o')
sns.lineplot(data=data, x='발생년', y='경상자수', label='경상자수', marker='o')
sns.lineplot(data=data, x='발생년', y='부상신고자수', label='부상신고자수', marker='o')
sns.set_style('darkgrid')
# 그래프 제목과 축 레이블 설정
plt.rc('font', family='NanumBarunGothic')
plt.title('최근 5년 동안의 피해규모')
plt.xlabel('년도')
plt.ylabel('건수')
# Out:
# Text(0, 0.5, '건수')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# CSV 파일 읽기
file_path = '/content/도로교통공단_시도 시군구별 교통사고 통계_20221231.csv'
data = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['시군구', '사고건수', '경상자수', '부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

plt.figure(figsize=(12, 6))

# '시도'를 기준으로 그룹화하여 '사망자수'와 '중상자수'의 합계 계산
grouped_data = data.groupby('시도')[['사망자수', '중상자수']].sum().reset_index()

# 바차트 그리기
bar_width = 0.35
bar_positions1 = range(len(grouped_data))
bar_positions2 = [pos + bar_width for pos in bar_positions1]

plt.bar(bar_positions1, grouped_data['사망자수'], width=bar_width, label='사망자수', color='skyblue')
plt.bar(bar_positions2, grouped_data['중상자수'], width=bar_width, label='중상자수', color='salmon')

# 그래프 제목과 축 레이블 설정
plt.title('시도별 교통사고 사망자수 및 중상자수')
plt.xlabel('시도')
plt.ylabel('건수')

# X 축에 시도 이름 표시
plt.xticks([pos + bar_width / 2 for pos in bar_positions1], grouped_data['시도'])

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# CSV 파일 읽기
file_path = '/content/도로교통공단_사고유형별 교통사고 통계_20221231.csv'
data = pd.read_csv(file_path, encoding='cp949')
# '사고유형'별 사고건수를 계산
accident_type_counts = data.groupby('사고유형')['사고건수'].sum().reset_index()

plt.figure(figsize=(12, 8))

sns.barplot(x='사고건수', y='사고유형', data=accident_type_counts, palette='viridis')
sns.set(style="whitegrid")

plt.rc('font', family='NanumBarunGothic')
plt.title('사고유형별 교통사고 사고건수')
plt.xlabel('사고건수')
plt.ylabel('사고유형')
# Out:
# Text(0, 0.5, '사고유형')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# CSV 파일 읽기
file_path = '/content/도로교통공단_가해운전자 연령층별 월별 교통사고 통계_20221231.csv'
data = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['발생월','사망자수', '중상자수', '경상자수', '부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)


plt.figure(figsize=(15, 8))

sns.barplot(x='가해자연령층', y='사고건수', data=data, palette='mako')
sns.set(style="whitegrid")
plt.rc('font', family='NanumBarunGothic')
plt.title('가해자 연령층별 교통사고 사고건수')
plt.xlabel('가해자 연령층')
plt.ylabel('사고건수')

# 그래프 표시
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

filename = '/content/도로교통공단_음주운전 교통사고 다발지역.csv'

df = pd.read_csv(filename, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['사고다발지fid','사고다발지id','법정동코드','지점코드','지점명','사고건수','사상자수',
                   '중상자수','경상자수','부상신고자수','경도','위도','다발지역폴리곤']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

df['시도'] = df['시도시군구명'].apply(lambda x: x.split()[0])

result = df.groupby(df['시도'])['사망자수'].sum()

colors = sns.color_palette("pastel", len(result))

plt.figure(figsize=(30, 6))

sns.lineplot(result, marker='o', color='r')

plt.xlabel('시도')
plt.ylabel('사망자수')
plt.title('시도별 음주운전으로 인한 교통사고 사망자수')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 읽기
file_path = '/content/경찰청_기상상태별 졸음운전 교통사고 현황_20201231.csv'
data = pd.read_csv(file_path, encoding='cp949')

# '구분'별 '사고(건)' 통계 계산
accident_counts = data.groupby('구분')['사고(건)'].sum().reset_index()

# 가장 큰 값 3개만 선택
top3_values = accident_counts.nlargest(3, '사고(건)')

# 나머지 값들을 더해서 '기타' 항목 생성
other_value = accident_counts[~accident_counts['구분'].isin(top3_values['구분'])]['사고(건)'].sum()
other_row = pd.DataFrame({'구분': ['기타'], '사고(건)': [other_value]})

# 합쳐서 새로운 데이터프레임 생성
accident_counts_top3 = pd.concat([top3_values, other_row])

colors = ['#4A90E2', '#4169E1', '#000080', '#4682B4']

# 도넛차트로 시각화
plt.figure(figsize=(10, 10))
wedges, texts, autotexts = plt.pie(
    accident_counts_top3['사고(건)'],
    labels=accident_counts_top3['구분'],
    autopct=lambda pct: f'{pct:.1f}%',
    startangle=90,
    counterclock=False,
    colors=colors,
    wedgeprops=dict(width=0.4),
    textprops={'fontsize': 9,'color': 'white'},
)

for label, autotext in zip(accident_counts_top3['구분'], autotexts):
    x, y = autotext.get_position()
    if label == '맑음':
        autotext.set_position((x, y -0.2))
    else:
        autotext.set_position((x, y + 0.1))

# 비율을 그래프 안에 표시
plt.legend(accident_counts_top3['구분'], bbox_to_anchor=(1, 0.5), loc="center left", fontsize=8)

plt.title('기상상태별 졸음운전 교통사고 현황')

# 그래프 표시
plt.show()

# %% [markdown]
# 시도별 교통사고건수

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

file_path = '/content/도로교통공단_음주운전 교통사고 다발지역.csv'
df = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['사고다발지fid','사고다발지id','법정동코드','지점코드','지점명','사고건수','사망자수',
                   '중상자수','경상자수','부상신고자수','경도','위도','다발지역폴리곤']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

# 시도시군구 칼럼에서 시도만 추출
df['시도'] = df['시도시군구명'].apply(lambda x: x.split()[0])

# 시도별로 사상자수 합계 계산
df_sido = df.groupby('시도', as_index=False).agg({'위도': 'mean', '경도': 'mean', '사상자수': 'sum'})

# 대한민국 중심의 Folium 지도 생성
m = folium.Map(location=[36.5, 127.5], zoom_start=7)

# 시도별로 원형 마커로 사상자수 시각화
for index, row in df_sido.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],
        radius=row['사상자수'] / 50,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6,
        popup=f"{row['시도']} - 사상자수: {row['사상자수']}명"
    ).add_to(m)

# 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_489ab3d3da2a53ea7cb11816c39f76bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_489ab3d3da2a53ea7cb11816c39f76bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_489ab3d3da2a53ea7cb11816c39f76bb = L.map(
#                 &quot;map_489ab3d3da2a53ea7cb11816c39f76bb&quot;,
#                 {
#                     center: [36.5, 127.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e159fa0132ce9066897e1cb34dae51c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_489ab3d3da2a53ea7cb11816c39f76bb);
#
#
#             var circle_marker_dd2ec228c15feb90456113bb01ca8ff3 = L.circleMarker(
#                 [37.562303184991165, 128.09914704736042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.26, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_489ab3d3da2a53ea7cb11816c39f76bb);
#
#
#         var popup_4921eaad019cff50dd8b1bd0e23103dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f450b82cf9da31258b5996ae5182c57 = $(`&lt;div id=&quot;html_8f450b82cf9da31258b5996ae5182c57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강원도 - 사상자수: 63명&lt;/div&gt;`)[0];
#                 popup_4921eaad019cff50dd8b1bd0e23103dc.setContent(html_8f450b82cf9da31258b5996ae5182c57);
#
#
#
#         circle_marker_dd2ec228c15feb90456113bb01ca8ff3.bindPopup(popup_4921eaad019cff50dd8b1bd0e23103dc)
#         ;
#
#
#
#
#             var circle_marker_62ae69f74454be3e96794b7e26c732b0 = L.circleMarker(
#                 [37.37223860246418, 126.9939997953609],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21.56, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_489ab3d3da2a53ea7cb11816c39f76bb);
#
#
#         var popup_6bb60d287a0557bb63225a59a31c7327 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d99fc3b22c9109a7e96fe7108730cff6 = $(`&lt;div id=&quot;html_d99fc3b22c9109a7e96fe7108730cff6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 - 사상자수: 1078명&lt;/div&gt;`)[0];
#                 popup_6bb60d287a0557bb63225a59a31c7327.setContent(html_d99fc3b22c9109a7e96fe7108730cff6);
#
#
#
#         circle_marker_62ae69f74454be3e96794b7e26c732b0.bindPopup(popup_6bb60d287a0557bb63225a59a31c7327)
#         ;
#
#
#
#
#             var circle_marker_83b9e0359607cfc7d5c1d4f15d39de8a = L.circleMarker(
#                 [35.18677482453938, 128.67243488370727],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_489ab3d3da2a53ea7cb11816c39f76bb);
#
#
#         var popup_028a7084c894319522dde6d75c84c8e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72e40773e20066af58b246d463c856a6 = $(`&lt;div id=&quot;html_72e40773e20066af58b246d463c856a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경상남도 - 사상자수: 106명&lt;/div&gt;`)[0];
#                 popup_028a7084c894319522dde6d75c84c8e6.setContent(html_72e40773e20066af58b246d463c856a6);
#
#
#
#         circle_marker_83b9e0359607cfc7d5c1d4f15d39de8a.bindPopup(popup_028a7084c894319522dde6d75c84c8e6)
#         ;
#
#
#
#
#             var circle_marker_a2ec46ba7ad06b52641cbca49ca8c8d2 = L.circleMarker(
#                 [36.135874053635305, 128.70673117166342],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashAr

# %% [markdown]
# 시간대별 교통사고 발생현황

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 읽기
file_path = '/content/도로교통공단_시간대별 교통사고 통계_20221231.csv'
df = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['사망자수', '중상자수', '경상자수', '부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

#  사고건수(건)을 lineplot으로 시각화
plt.figure(figsize=(20, 6))
sns.lineplot(x='시간대', y='사고건수', data=df, marker='o', linestyle='--', color='#FFA800')
sns.set_style('darkgrid')
plt.title('시간대별 교통사고 건수')
plt.rc('font', family='NanumBarunGothic')
plt.xlabel('시간대', fontsize=10)
plt.ylabel('사고건수')

# 각 데이터 포인트에 값을 표시
for index, value in enumerate(df['사고건수']):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=8)

# x축 눈금 레이블에 대한 폰트 크기 설정
plt.xticks(fontsize=10)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV 파일 읽기
file_path = '/content/도로교통공단_요일별 교통사고 통계_20221231.csv'
df = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['중상자수',	'경상자수'	,'부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

plt.figure(figsize=(12,8))

# 사고건수(bar chart)
bar_plot = sns.barplot(x='요일', y='사고건수', data=df, color='#9999FF', label='사고건수')

# 사망자수(lineplot)
ax2 = plt.twinx()
sns.lineplot(x='요일', y='사망자수', data=df, color='#99FFFF', marker='o', label='사망자수', ax=ax2)

# 사고건수와 사망자수 값 그래프에 표시
for p, value, line_value in zip(bar_plot.patches, df['사고건수'], df['사망자수']):
    bar_plot.annotate(f'{value}', (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center', fontsize=9, color='#FFFF99', xytext=(0, -20),
                      textcoords='offset points')

    ax2.annotate(f'{line_value}', (p.get_x() + p.get_width() / 2., line_value),
                 ha='center', va='center', fontsize=9, color='black', xytext=(0, 10),
                 textcoords='offset points')

plt.title('요일별 교통사고 건수와 사망자수')
plt.xlabel('요일')
plt.ylabel('건수')
plt.legend()

# 눈금 값 제거
bar_plot.set_yticks([])
ax2.set_yticks([])
bar_plot.set_ylabel('')
ax2.set_ylabel('')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# CSV 파일 읽기
file_path = '/content/도로교통공단_시간대별 교통사고 통계_20221231.csv'
df = pd.read_csv(file_path, encoding='cp949')

# 삭제할 컬럼 목록
columns_to_drop = ['중상자수','경상자수','부상신고자수']

# 컬럼 삭제
df = df.drop(columns=columns_to_drop, axis=1)

plt.figure(figsize=(20,12))

# 사고건수(bar chart)
bar_plot = sns.barplot(x='시간대', y='사고건수', data=df, color='#99FF44', label='사고건수')

# 사망자수(lineplot)
ax2 = plt.twinx()
sns.lineplot(x='시간대', y='사망자수', data=df, color='#FFCC66', marker='o', label='사망자수', ax=ax2)

# 사고건수와 사망자수 값 그래프에 표시
for p, value, line_value in zip(bar_plot.patches, df['사고건수'], df['사망자수']):
    bar_plot.annotate(f'{value}', (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center', fontsize=9, color='#FFFF99', xytext=(0, -20),
                      textcoords='offset points')

    ax2.annotate(f'{line_value}', (p.get_x() + p.get_width() / 2., line_value),
                 ha='center', va='center', fontsize=9, color='black', xytext=(0, 10),
                 textcoords='offset points')

plt.title('시간대별 교통사고 건수와 사망자수')
plt.xlabel('시간대')
plt.ylabel('건수')
plt.legend()

# 눈금 값 제거
bar_plot.set_yticks([])
ax2.set_yticks([])
bar_plot.set_ylabel('')
ax2.set_ylabel('')

plt.show()
